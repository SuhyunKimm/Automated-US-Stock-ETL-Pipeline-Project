# %%
import finnhub
import pandas as pd
import numpy as np
import pyodbc

finnhub_client = finnhub.Client(api_key="d5q4p8hr01qq2b6afv1gd5q4p8hr01qq2b6afv20")

tickers = ["AMD", "NVDA", "AMZN", "PLTR", "TSLA", "AAPL"]
profile = []

for t in tickers :
    data = finnhub_client.company_profile2(symbol=t)
    profile.append(data)

df = pd.DataFrame(profile)
# Out:
#   country currency estimateCurrency                    exchange  \
# 0      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
# 1      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
# 2      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
# 3      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
# 4      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
# 5      US      USD              USD  NASDAQ NMS - GLOBAL MARKET
#
#   finnhubIndustry         ipo  \
# 0  Semiconductors  1979-10-15
# 1  Semiconductors  1999-01-22
# 2          Retail  1997-05-15
# 3      Technology  2020-09-30
# 4     Automobiles  2010-06-29
# 5      Technology  1980-12-12
#
#                                                 logo  marketCapitalization  \
# 0  https://static2.finnhub.io/file/publicdatany/f...          4.227698e+05
# 1  https://static2.finnhub.io/file/publicdatany/f...          4.560381e+06
# 2  https://static2.finnhub.io/file/publicdatany/f...          2.556672e+06
# 3  https://static2.finnhub.io/file/publicdatany/f...          4.042311e+05
# 4  https://static2.finnhub.io/file/publicdatany/f...          1.493492e+06
# 5  https://static2.finnhub.io/file/publicdatany/f...          3.645673e+06
#
#                          name        phone  shareOutstanding ticker  \
# 0  Advanced Micro Devices Inc  14087494000           1628.04    AMD
# 1                 NVIDIA Corp  14084862000          24300.00   NVDA
# 2              Amazon.com Inc  12062661000          10690.22   AMZN
# 3   Palantir Technologies Inc  17203583679           2382.43   PLTR
# 4                   Tesla Inc  15125168177           3325.82   TSLA
# 5                   Apple Inc  14089961010          14776.35   AAPL
#
#                       weburl
# 0       https://www.amd.com/
# 1    https://www.nvidia.com/
# 2    https://www.amazon.com/
# 3  https://www.palantir.com/
# 4     https://www.tesla.com/
# 5     https://www.apple.com/

# %%
"""
tickerId
ticker
company_Name
sector
industry
market
currency
"""
